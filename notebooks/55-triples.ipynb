# %% [markdown]
# # Assignment #5: Extraction of subject–verb–object triples
# Author: Pierre Nugues

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this assignment, you will extract relations from a parsed sentence involving two words or entities. You will start with pairs of words, namely a subject and its verb, and then extend your programs to triples: subject, verb, and object. In the triples, the subject and the object are the entities, and the verb represents the relation.
#
# $$
# \text{Subject} \xrightarrow[\text{}]{\text{Verb}} \text{Object}
# $$
#
# The overall work is inspired by the _Prismatic_ knowledge base used in the IBM Watson system, where the subject, verb, and object triples are a way to extract knowledge from text.  See <a href="http://www.aclweb.org/anthology/W/W10/W10-0915.pdf">this paper</a> for details.
#
# You will apply the extraction to multilingual texts:
# 1. First you will use a parsed corpus of Swedish; and then
# 2. You will apply it to other languages.
#
# The objectives of this assignment are to:
# * Extract the subject–verb pairs from a parsed corpus
# * Extend the extraction to subject–verb–object triples
# * Understand how dependency parsing can help create a knowledge base
# * Write a short report of 1 to 2 pages on the assignment

# %% [markdown]
# ## Corpus

# %% [markdown]
# As corpora, you will use the Universal Dependencies: https://universaldependencies.org/.
# 1. In the first part of the assignment, you will focus on Swedish as it is easier to understand for most students, and then
# 2. Move on to all the other languages.
#
# You will only consider the training sets of each corpus.

# %% [markdown]
# ### Choosing a parsed corpus

# %% [markdown]
# 1. Download the latest version of Universal dependencies (2.6) and uncompress them. You have a local version in the `/usr/local/cs/EDAN20/` folder on LTH's machines;
# 2. Go to the Swedish _Talbanken_ corpus;
# 3. Read the CoNLL-U annotation here: https://universaldependencies.org/format.html

# %% [markdown]
# ### Examining the annotation

# %% [markdown]
# You will carry out the following steps and describe them in your report:
#
# 1. Draw graphical representations of the two first Swedish sentences of the training set. You will include these drawings in your report;
# 2. Visualize these sentences with this tool: http://spyysalo.github.io/conllu.js/ and check that you have the same results;
# 3. Apply the dependency parser for Swedish of the <a href="http://vilde.cs.lth.se:9000/">Langforia pipelines</a> to these sentences (only the text of each sentence). You will have to select Swedish and activate both `Token` and `DependencyRelation`. Link to Lanforia pipelines: <a href="http://vilde.cs.lth.se:9000/">http://vilde.cs.lth.se:9000/</a>. You will describe possible differences.

# %% [markdown]
# ## Programming

# %% [markdown]
# ### Swedish

# %% [markdown]
# You will extract all the subject–verb pairs and the subject–verb–object triples from the Swedish _Talbanken_ training corpus. To start the program, you can use the CoNLL-U reader available in the cells below.
# This program works for the other corpora. You can also program a reader yourself starting from the one you used to read the CoNLL 2000 format in the fourth lab or from scratch.

# %% [markdown]
# #### Imports

# %%
import os
import regex as re

# %% [markdown]
# ### Corpus location

# %% [markdown]
# Here are the corpus locations you will use. You may have to adjust `ud_path`.

# %%
ud_path = 'corpus/ud-treebanks-v2.6/'

# %%
path_sv = ud_path + 'UD_Swedish-Talbanken/sv_talbanken-ud-train.conllu'
path_fr = ud_path + 'UD_French-GSD/fr_gsd-ud-train.conllu'
path_ru = ud_path + 'UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu'
path_en = ud_path + 'UD_English-EWT/en_ewt-ud-train.conllu'

# %% [markdown]
# The column names of the CoNLL-U corpora

# %%
column_names_u = ['ID', 'FORM', 'LEMMA', 'UPOS', 'XPOS', 'FEATS', 'HEAD', 'DEPREL', 'DEPS', 'MISC']

# %% [markdown]
# #### Functions to read the CoNLL-U files

# %%
def read_sentences(file):
    """
    Creates a list of sentences from the corpus
    Each sentence is a string
    :param file:
    :return:
    """
    f = open(file).read().strip()
    sentences = f.split('\n\n')
    return sentences

# %%
def split_rows(sentences, column_names):
    """
    Creates a list of sentence where each sentence is a list of lines
    Each line is a dictionary of columns
    :param sentences:
    :param column_names:
    :return:
    """
    new_sentences = []
    root_values = ['0', 'ROOT', 'ROOT', 'ROOT', 'ROOT', 'ROOT', '0', 'ROOT', '0', 'ROOT']
    start = [dict(zip(column_names, root_values))]
    for sentence in sentences:
        rows = sentence.split('\n')
        sentence = [dict(zip(column_names, row.split('\t'))) for row in rows if row[0] != '#']
        sentence = start + sentence
        new_sentences.append(sentence)
    return new_sentences

# %% [markdown]
# #### Reading the corpus

# %% [markdown]
# We load the Swedish Talbanken corpus.

# %%
sentences = read_sentences(path_sv)
formatted_corpus = split_rows(sentences, column_names_u)

# %%
len(formatted_corpus)
# Out:
# 4303

# %% [markdown]
# The parsed sentence: _Genom skattereformen införs individuell beskattning (särbeskattning) av arbetsinkomster._

# %%
formatted_corpus[1]
# Out:
# [{'ID': '0',
#   'FORM': 'ROOT',
#   'LEMMA': 'ROOT',
#   'UPOS': 'ROOT',
#   'XPOS': 'ROOT',
#   'FEATS': 'ROOT',
#   'HEAD': '0',
#   'DEPREL': 'ROOT',
#   'DEPS': '0',
#   'MISC': 'ROOT'},
#  {'ID': '1',
#   'FORM': 'Genom',
#   'LEMMA': 'genom',
#   'UPOS': 'ADP',
#   'XPOS': 'PP',
#   'FEATS': '_',
#   'HEAD': '2',
#   'DEPREL': 'case',
#   'DEPS': '2:case',
#   'MISC': '_'},
#  {'ID': '2',
#   'FORM': 'skattereformen',
#   'LEMMA': 'skattereform',
#   'UPOS': 'NOUN',
#   'XPOS': 'NN|UTR|SIN|DEF|NOM',
#   'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Sing',
#   'HEAD': '3',
#   'DEPREL': 'obl',
#   'DEPS': '3:obl:genom',
#   'MISC': '_'},
#  {'ID': '3',
#   'FORM': 'införs',
#   'LEMMA': 'införa',
#   'UPOS': 'VERB',
#   'XPOS': 'VB|PRS|SFO',
#   'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Pass',
#   'HEAD': '0',
#   'DEPREL': 'root',
#   'DEPS': '0:root',
#   'MISC': '_'},
#  {'ID': '4',
#   'FORM': 'individuell',
#   'LEMMA': 'individuell',
#   'UPOS': 'ADJ',
#   'XPOS': 'JJ|POS|UTR|SIN|IND|NOM',
#   'FEATS': 'Case=Nom|Definite=Ind|Degree=Pos|Gender=Com|Number=Sing',
#   'HEAD': '5',
#   'DEPREL': 'amod',
#   'DEPS': '5:amod',
#   'MISC': '_'},
#  {'ID': '5',
#   'FORM': 'beskattning',
#   'LEMMA': 'beskattning',
#   'UPOS': 'NOUN',
#   'XPOS': 'NN|UTR|SIN|IND|NOM',
#   'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#   'HEAD': '3',
#   'DEPREL': 'nsubj:pass',
#   'DEPS': '3:nsubj:pass',
#   'MISC': '_'},
#  {'ID': '6',
#   'FORM': '(',
#   'LEMMA': '(',
#   'UPOS': 'PUNCT',
#   'XPOS': 'PAD',
#   'FEATS': '_',
#   'HEAD': '5',
#   'DEPREL': 'punct',
#   'DEPS': '5:punct',
#   'MISC': 'SpaceAfter=No'},
#  {'ID': '7',
#   'FORM': 'särbeskattning',
#   'LEMMA': 'särbeskattning',
#   'UPOS': 'NOUN',
#   'XPOS': 'NN|UTR|SIN|IND|NOM',
#   'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#   'HEAD': '5',
#   'DEPREL': 'appos',
#   'DEPS': '5:appos',
#   'MISC': 'SpaceAfter=No'},
#  {'ID': '8',
#   'FORM': ')',
#   'LEMMA': ')',
#   'UPOS': 'PUNCT',
#   'XPOS': 'PAD',
#   'FEATS': '_',
#   'HEAD': '5',
#   'DEPREL': 'punct',
#   'DEPS': '5:punct',
#   'MISC': '_'},
#  {'ID': '9',
#   'FORM': 'av',
#   'LEMMA': 'av',
#   'UPOS': 'ADP',
#   'XPOS': 'PP',
#   'FEATS': '_',
#   'HEAD': '10',
#   'DEPREL': 'case',
#   'DEPS': '10:case',
#   'MISC': '_'},
#  {'ID': '10',
#   'FORM': 'arbetsinkomster',
#   'LEMMA': 'arbetsinkomst',
#   'UPOS': 'NOUN',
#   'XPOS': 'NN|UTR|PLU|IND|NOM',
#   'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Plur',
#   'HEAD': '5',
#   'DEPREL': 'nmod',
#   'DEPS': '5:nmod:av',
#   'MISC': 'SpaceAfter=No'},
#  {'ID': '11',
#   'FORM': '.',
#   'LEMMA': '.',
#   'UPOS': 'PUNCT',
#   'XPOS': 'MAD',
#   'FEATS': '_',
#   'HEAD': '3',
#   'DEPREL': 'punct',
#   'DEPS': '3:punct',
#   'MISC': '_'}]

# %% [markdown]
# #### Converting the lists in dictionaries

# %% [markdown]
# To ease the processing of some corpora, you will use a dictionary represention of the sentences. The keys will be the `ID` values. We do this because `ID` is not necessarily a number.

# %%
def convert_to_dict(formatted_corpus):
    """
    Converts each sentence from a list of words to a dictionary where the keys are id
    :param formatted_corpus:
    :return:
    """
    formatted_corpus_dict = []
    for sentence in formatted_corpus:
        sentence_dict = {}
        for word in sentence:
            sentence_dict[word['ID']] = word
        formatted_corpus_dict.append(sentence_dict)
    return formatted_corpus_dict

# %%
formatted_corpus_dict = convert_to_dict(formatted_corpus)
formatted_corpus_dict[20:50]
# Out:
# [{'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Med',
#    'LEMMA': 'med',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '2',
#    'DEPREL': 'case',
#    'DEPS': '2:case',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'makar',
#    'LEMMA': 'make',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|PLU|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Plur',
#    'HEAD': '3',
#    'DEPREL': 'obl',
#    'DEPS': '3:obl:med',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'likställs',
#    'LEMMA': 'likställa',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|SFO',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Pass',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'de',
#    'LEMMA': 'de',
#    'UPOS': 'PRON',
#    'XPOS': 'PN|UTR/NEU|PLU|DEF|SUB',
#    'FEATS': 'Case=Nom|Definite=Def|Number=Plur|PronType=Prs',
#    'HEAD': '3',
#    'DEPREL': 'nsubj:pass',
#    'DEPS': '3:nsubj:pass|10:nsubj',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'som',
#    'LEMMA': 'som',
#    'UPOS': 'PRON',
#    'XPOS': 'HP|-|-|-',
#    'FEATS': 'PronType=Rel',
#    'HEAD': '10',
#    'DEPREL': 'nsubj',
#    'DEPS': '4:ref',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'utan',
#    'LEMMA': 'utan',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '9',
#    'DEPREL': 'mark',
#    'DEPS': '9:mark',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'att',
#    'LEMMA': 'att',
#    'UPOS': 'PART',
#    'XPOS': 'IE',
#    'FEATS': '_',
#    'HEAD': '9',
#    'DEPREL': 'mark',
#    'DEPS': '9:mark',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'vara',
#    'LEMMA': 'vara',
#    'UPOS': 'AUX',
#    'XPOS': 'VB|INF|AKT',
#    'FEATS': 'VerbForm=Inf|Voice=Act',
#    'HEAD': '9',
#    'DEPREL': 'cop',
#    'DEPS': '9:cop',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': 'gifta',
#    'LEMMA': 'gift',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRF|UTR/NEU|PLU|IND/DEF|NOM',
#    'FEATS': 'Case=Nom|Number=Plur|Tense=Past|VerbForm=Part',
#    'HEAD': '10',
#    'DEPREL': 'advcl',
#    'DEPS': '10:advcl:att',
#    'MISC': '_'},
#   '10': {'ID': '10',
#    'FORM': 'lever',
#    'LEMMA': 'leva',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '4',
#    'DEPREL': 'acl:relcl',
#    'DEPS': '4:acl:relcl',
#    'MISC': '_'},
#   '11': {'ID': '11',
#    'FORM': 'tillsammans',
#    'LEMMA': 'tillsammans',
#    'UPOS': 'ADV',
#    'XPOS': 'AB',
#    'FEATS': '_',
#    'HEAD': '10',
#    'DEPREL': 'advmod',
#    'DEPS': '10:advmod',
#    'MISC': '_'},
#   '12': {'ID': '12',
#    'FORM': 'om',
#    'LEMMA': 'om',
#    'UPOS': 'SCONJ',
#    'XPOS': 'SN',
#    'FEATS': '_',
#    'HEAD': '16',
#    'DEPREL': 'mark',
#    'DEPS': '16:mark',
#    'MISC': '_'},
#   '13': {'ID': '13',
#    'FORM': 'de',
#    'LEMMA': 'de',
#    'UPOS': 'PRON',
#    'XPOS': 'PN|UTR/NEU|PLU|DEF|SUB',
#    'FEATS': 'Case=Nom|Definite=Def|Number=Plur|PronType=Prs',
#    'HEAD': '16',
#    'DEPREL': 'nsubj',
#    'DEPS': '16:nsubj|20:nsubj',
#    'MISC': '_'},
#   '14': {'ID': '14',
#    'FORM': 'tidigare',
#    'LEMMA': 'tidig',
#    'UPOS': 'ADV',
#    'XPOS': 'AB|KOM',
#    'FEATS': 'Degree=Cmp',
#    'HEAD': '16',
#    'DEPREL': 'advmod',
#    'DEPS': '16:advmod',
#    'MISC': '_'},
#   '15': {'ID': '15',
#    'FORM': 'varit',
#    'LEMMA': 'vara',
#    'UPOS': 'AUX',
#    'XPOS': 'VB|SUP|AKT',
#    'FEATS': 'VerbForm=Sup|Voice=Act',
#    'HEAD': '16',
#    'DEPREL': 'cop',
#    'DEPS': '16:cop',
#    'MISC': '_'},
#   '16': {'ID': '16',
#    'FORM': 'gifta',
#    'LEMMA': 'gift',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRF|UTR/NEU|PLU|IND/DEF|NOM',
#    'FEATS': 'Case=Nom|Number=Plur|Tense=Past|VerbForm=Part',
#    'HEAD': '3',
#    'DEPREL': 'advcl',
#    'DEPS': '3:advcl:om',
#    'MISC': '_'},
#   '17': {'ID': '17',
#    'FORM': 'med',
#    'LEMMA': 'med',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '18',
#    'DEPREL': 'case',
#    'DEPS': '18:case',
#    'MISC': '_'},
#   '18': {'ID': '18',
#    'FORM': 'varandra',
#    'LEMMA': 'varandra',
#    'UPOS': 'PRON',
#    'XPOS': 'PN|UTR/NEU|PLU|DEF|OBJ',
#    'FEATS': 'Case=Acc|Definite=Def|Number=Plur|PronType=Rcp',
#    'HEAD': '16',
#    'DEPREL': 'obl',
#    'DEPS': '16:obl:med',
#    'MISC': '_'},
#   '19': {'ID': '19',
#    'FORM': 'eller',
#    'LEMMA': 'eller',
#    'UPOS': 'CCONJ',
#    'XPOS': 'KN',
#    'FEATS': '_',
#    'HEAD': '20',
#    'DEPREL': 'cc',
#    'DEPS': '20:cc',
#    'MISC': '_'},
#   '20': {'ID': '20',
#    'FORM': 'har',
#    'LEMMA': 'ha',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '16',
#    'DEPREL': 'conj',
#    'DEPS': '3:advcl:om|16:conj:eller',
#    'MISC': '_'},
#   '21': {'ID': '21',
#    'FORM': 'eller',
#    'LEMMA': 'eller',
#    'UPOS': 'CCONJ',
#    'XPOS': 'KN',
#    'FEATS': '_',
#    'HEAD': '23',
#    'DEPREL': 'cc',
#    'DEPS': '23:cc',
#    'MISC': '_'},
#   '22': {'ID': '22',
#    'FORM': 'har',
#    'LEMMA': 'ha',
#    'UPOS': 'AUX',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '23',
#    'DEPREL': 'aux',
#    'DEPS': '23:aux',
#    'MISC': '_'},
#   '23': {'ID': '23',
#    'FORM': 'haft',
#    'LEMMA': 'ha',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|SUP|AKT',
#    'FEATS': 'VerbForm=Sup|Voice=Act',
#    'HEAD': '20',
#    'DEPREL': 'conj',
#    'DEPS': '20:conj:eller',
#    'MISC': '_'},
#   '24': {'ID': '24',
#    'FORM': 'barn',
#    'LEMMA': 'barn',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '20',
#    'DEPREL': 'obj',
#    'DEPS': '20:obj|23:obj',
#    'MISC': '_'},
#   '25': {'ID': '25',
#    'FORM': 'gemensamt',
#    'LEMMA': 'gemensam',
#    'UPOS': 'ADV',
#    'XPOS': 'AB|POS',
#    'FEATS': 'Degree=Pos',
#    'HEAD': '20',
#    'DEPREL': 'advmod',
#    'DEPS': '20:advmod',
#    'MISC': 'SpaceAfter=No'},
#   '26': {'ID': '26',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '3',
#    'DEPREL': 'punct',
#    'DEPS': '3:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Höjt',
#    'LEMMA': 'höja',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRF|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing|Tense=Past|VerbForm=Part',
#    'HEAD': '2',
#    'DEPREL': 'amod',
#    'DEPS': '2:amod',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'avdrag',
#    'LEMMA': 'avdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'för',
#    'LEMMA': 'för',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '4',
#    'DEPREL': 'case',
#    'DEPS': '4:case',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'underhållsbidrag',
#    'LEMMA': 'underhållsbidrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '2',
#    'DEPREL': 'nmod',
#    'DEPS': '2:nmod:för',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'till',
#    'LEMMA': 'till',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '8',
#    'DEPREL': 'case',
#    'DEPS': '8:case',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'icke',
#    'LEMMA': 'icke',
#    'UPOS': 'PART',
#    'XPOS': 'AB',
#    'FEATS': 'Polarity=Neg',
#    'HEAD': '8',
#    'DEPREL': 'advmod',
#    'DEPS': '8:advmod',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'hemmavarande',
#    'LEMMA': 'hemmavarande',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR/NEU|SIN/PLU|IND/DEF|NOM',
#    'FEATS': 'Case=Nom|Degree=Pos',
#    'HEAD': '8',
#    'DEPREL': 'amod',
#    'DEPS': '8:amod',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'barn',
#    'LEMMA': 'barn',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '4',
#    'DEPREL': 'nmod',
#    'DEPS': '4:nmod:till',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Avdrag',
#    'LEMMA': 'avdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|PLU|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Plur',
#    'HEAD': '9',
#    'DEPREL': 'nsubj:pass',
#    'DEPS': '9:nsubj:pass',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'för',
#    'LEMMA': 'för',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '4',
#    'DEPREL': 'case',
#    'DEPS': '4:case',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'utgivet',
#    'LEMMA': 'utge',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRF|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing|Tense=Past|VerbForm=Part',
#    'HEAD': '4',
#    'DEPREL': 'amod',
#    'DEPS': '4:amod',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'underhållsbidrag',
#    'LEMMA': 'underhållsbidrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '1',
#    'DEPREL': 'nmod',
#    'DEPS': '1:nmod:för',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'till',
#    'LEMMA': 'till',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '8',
#    'DEPREL': 'case',
#    'DEPS': '8:case',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'icke',
#    'LEMMA': 'icke',
#    'UPOS': 'PART',
#    'XPOS': 'AB',
#    'FEATS': 'Polarity=Neg',
#    'HEAD': '8',
#    'DEPREL': 'advmod',
#    'DEPS': '8:advmod',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'hemmavarande',
#    'LEMMA': 'hemmavarande',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR/NEU|SIN/PLU|IND/DEF|NOM',
#    'FEATS': 'Case=Nom|Degree=Pos',
#    'HEAD': '8',
#    'DEPREL': 'amod',
#    'DEPS': '8:amod',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'barn',
#    'LEMMA': 'barn',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '4',
#    'DEPREL': 'nmod',
#    'DEPS': '4:nmod:till',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': 'höjs',
#    'LEMMA': 'höja',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|SFO',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Pass',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '10': {'ID': '10',
#    'FORM': 'från',
#    'LEMMA': 'från',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '12',
#    'DEPREL': 'case',
#    'DEPS': '12:case',
#    'MISC': '_'},
#   '11': {'ID': '11',
#    'FORM': '1000',
#    'LEMMA': '1000',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '12',
#    'DEPREL': 'nummod',
#    'DEPS': '12:nummod',
#    'MISC': '_'},
#   '12': {'ID': '12',
#    'FORM': 'kr',
#    'LEMMA': 'kr',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|AN',
#    'FEATS': 'Abbr=Yes',
#    'HEAD': '9',
#    'DEPREL': 'obl',
#    'DEPS': '9:obl:från',
#    'MISC': '_'},
#   '13': {'ID': '13',
#    'FORM': 'till',
#    'LEMMA': 'till',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '15',
#    'DEPREL': 'case',
#    'DEPS': '15:case',
#    'MISC': '_'},
#   '14': {'ID': '14',
#    'FORM': '1500',
#    'LEMMA': '1500',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '15',
#    'DEPREL': 'nummod',
#    'DEPS': '15:nummod',
#    'MISC': '_'},
#   '15': {'ID': '15',
#    'FORM': 'kr',
#    'LEMMA': 'kr',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|AN',
#    'FEATS': 'Abbr=Yes',
#    'HEAD': '9',
#    'DEPREL': 'obl',
#    'DEPS': '9:obl:till',
#    'MISC': '_'},
#   '16': {'ID': '16',
#    'FORM': 'per',
#    'LEMMA': 'per',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '17',
#    'DEPREL': 'case',
#    'DEPS': '17:case',
#    'MISC': '_'},
#   '17': {'ID': '17',
#    'FORM': 'barn',
#    'LEMMA': 'barn',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '9',
#    'DEPREL': 'obl',
#    'DEPS': '9:obl:per',
#    'MISC': '_'},
#   '18': {'ID': '18',
#    'FORM': 'och',
#    'LEMMA': 'och',
#    'UPOS': 'CCONJ',
#    'XPOS': 'KN',
#    'FEATS': '_',
#    'HEAD': '19',
#    'DEPREL': 'cc',
#    'DEPS': '19:cc',
#    'MISC': '_'},
#   '19': {'ID': '19',
#    'FORM': 'år',
#    'LEMMA': 'år',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '17',
#    'DEPREL': 'conj',
#    'DEPS': '9:obl:per|17:conj:och',
#    'MISC': 'SpaceAfter=No'},
#   '20': {'ID': '20',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '9',
#    'DEPREL': 'punct',
#    'DEPS': '9:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Dessutom',
#    'LEMMA': 'dessutom',
#    'UPOS': 'ADV',
#    'XPOS': 'AB',
#    'FEATS': '_',
#    'HEAD': '2',
#    'DEPREL': 'advmod',
#    'DEPS': '2:advmod',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'höjs',
#    'LEMMA': 'höja',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|SFO',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Pass',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'åldergränsen',
#    'LEMMA': 'åldergräns',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Sing',
#    'HEAD': '2',
#    'DEPREL': 'nsubj:pass',
#    'DEPS': '2:nsubj:pass',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'till',
#    'LEMMA': 'till',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '6',
#    'DEPREL': 'case',
#    'DEPS': '6:case',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': '18',
#    'LEMMA': '18',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '6',
#    'DEPREL': 'nummod',
#    'DEPS': '6:nummod',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'år',
#    'LEMMA': 'år',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|PLU|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Plur',
#    'HEAD': '2',
#    'DEPREL': 'obl',
#    'DEPS': '2:obl:till',
#    'MISC': 'SpaceAfter=No'},
#   '7': {'ID': '7',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '2',
#    'DEPREL': 'punct',
#    'DEPS': '2:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'När',
#    'LEMMA': 'när',
#    'UPOS': 'ADV',
#    'XPOS': 'HA',
#    'FEATS': '_',
#    'HEAD': '6',
#    'DEPREL': 'case',
#    'DEPS': '6:case',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'det',
#    'LEMMA': 'den',
#    'UPOS': 'PRON',
#    'XPOS': 'PN|NEU|SIN|DEF|SUB/OBJ',
#    'FEATS': 'Definite=Def|Gender=Neut|Number=Sing|PronType=Prs',
#    'HEAD': '1',
#    'DEPREL': 'fixed',
#    'DEPS': '1:fixed',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'gäller',
#    'LEMMA': 'gälla',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '1',
#    'DEPREL': 'fixed',
#    'DEPS': '1:fixed',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': '1972',
#    'LEMMA': '1972',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '5',
#    'DEPREL': 'nummod',
#    'DEPS': '5:nummod',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'års',
#    'LEMMA': 'år',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|GEN',
#    'FEATS': 'Case=Gen|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '6',
#    'DEPREL': 'nmod:poss',
#    'DEPS': '6:nmod:poss',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'taxering',
#    'LEMMA': 'taxering',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '10',
#    'DEPREL': 'obl',
#    'DEPS': '10:obl:när_det_gäller',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'skall',
#    'LEMMA': 'skola',
#    'UPOS': 'AUX',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '10',
#    'DEPREL': 'aux',
#    'DEPS': '10:aux',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'barnet',
#    'LEMMA': 'barn',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Neut|Number=Sing',
#    'HEAD': '10',
#    'DEPREL': 'nsubj',
#    'DEPS': '10:nsubj',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': 'vara',
#    'LEMMA': 'vara',
#    'UPOS': 'AUX',
#    'XPOS': 'VB|INF|AKT',
#    'FEATS': 'VerbForm=Inf|Voice=Act',
#    'HEAD': '10',
#    'DEPREL': 'cop',
#    'DEPS': '10:cop',
#    'MISC': '_'},
#   '10': {'ID': '10',
#    'FORM': 'fött',
#    'LEMMA': 'föda',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRF|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing|Tense=Past|VerbForm=Part',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '11': {'ID': '11',
#    'FORM': 'efter',
#    'LEMMA': 'efter',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '14',
#    'DEPREL': 'case',
#    'DEPS': '14:case',
#    'MISC': '_'},
#   '12': {'ID': '12',
#    'FORM': 'den',
#    'LEMMA': 'en',
#    'UPOS': 'DET',
#    'XPOS': 'DT|UTR|SIN|DEF',
#    'FEATS': 'Definite=Def|Gender=Com|Number=Sing|PronType=Art',
#    'HEAD': '14',
#    'DEPREL': 'det',
#    'DEPS': '14:det',
#    'MISC': '_'},
#   '13': {'ID': '13',
#    'FORM': '1',
#    'LEMMA': '1',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '14',
#    'DEPREL': 'nummod',
#    'DEPS': '14:nummod',
#    'MISC': '_'},
#   '14': {'ID': '14',
#    'FORM': 'november',
#    'LEMMA': 'november',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '10',
#    'DEPREL': 'obl',
#    'DEPS': '10:obl:efter',
#    'MISC': '_'},
#   '15': {'ID': '15',
#    'FORM': '1953',
#    'LEMMA': '1953',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '14',
#    'DEPREL': 'nummod',
#    'DEPS': '14:nummod',
#    'MISC': 'SpaceAfter=No'},
#   '16': {'ID': '16',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '10',
#    'DEPREL': 'punct',
#    'DEPS': '10:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Kravet',
#    'LEMMA': 'krav',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Neut|Number=Sing',
#    'HEAD': '5',
#    'DEPREL': 'nsubj:pass',
#    'DEPS': '5:nsubj:pass',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'på',
#    'LEMMA': 'på',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '3',
#    'DEPREL': 'case',
#    'DEPS': '3:case',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'bevisning',
#    'LEMMA': 'bevisning',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '1',
#    'DEPREL': 'nmod',
#    'DEPS': '1:nmod:på',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'har',
#    'LEMMA': 'ha',
#    'UPOS': 'AUX',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '5',
#    'DEPREL': 'aux',
#    'DEPS': '5:aux',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'mildrats',
#    'LEMMA': 'mildra',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|SUP|SFO',
#    'FEATS': 'VerbForm=Sup|Voice=Pass',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': 'SpaceAfter=No'},
#   '6': {'ID': '6',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '5',
#    'DEPREL': 'punct',
#    'DEPS': '5:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Avdraget',
#    'LEMMA': 'avdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Neut|Number=Sing',
#    'HEAD': '5',
#    'DEPREL': 'nsubj:pass',
#    'DEPS': '5:nsubj:pass',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'måste',
#    'LEMMA': 'måste',
#    'UPOS': 'AUX',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '5',
#    'DEPREL': 'aux',
#    'DEPS': '5:aux',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'inte',
#    'LEMMA': 'inte',
#    'UPOS': 'PART',
#    'XPOS': 'AB',
#    'FEATS': 'Polarity=Neg',
#    'HEAD': '5',
#    'DEPREL': 'advmod',
#    'DEPS': '5:advmod',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'längre',
#    'LEMMA': 'länge',
#    'UPOS': 'ADV',
#    'XPOS': 'AB|KOM',
#    'FEATS': 'Degree=Cmp',
#    'HEAD': '5',
#    'DEPREL': 'advmod',
#    'DEPS': '5:advmod',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'styrkas',
#    'LEMMA': 'styrka',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|INF|SFO',
#    'FEATS': 'VerbForm=Inf|Voice=Pass',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'med',
#    'LEMMA': 'med',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '7',
#    'DEPREL': 'case',
#    'DEPS': '7:case',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'intyg',
#    'LEMMA': 'intyg',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '5',
#    'DEPREL': 'obl',
#    'DEPS': '5:obl:med',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'från',
#    'LEMMA': 'från',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '9',
#    'DEPREL': 'case',
#    'DEPS': '9:case',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': 'barnavårdsnämnd',
#    'LEMMA': 'barnavårdsnämnd',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '7',
#    'DEPREL': 'nmod',
#    'DEPS': '7:nmod:från',
#    'MISC': 'SpaceAfter=No'},
#   '10': {'ID': '10',
#    'FORM': ',',
#    'LEMMA': ',',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MID',
#    'FEATS': '_',
#    'HEAD': '11',
#    'DEPREL': 'punct',
#    'DEPS': '11:punct',
#    'MISC': '_'},
#   '11': {'ID': '11',
#    'FORM': 'barnavårdsman',
#    'LEMMA': 'barnavårdsman',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '9',
#    'DEPREL': 'conj',
#    'DEPS': '7:nmod:från|9:conj:eller',
#    'MISC': '_'},
#   '12': {'ID': '12',
#    'FORM': 'eller',
#    'LEMMA': 'eller',
#    'UPOS': 'CCONJ',
#    'XPOS': 'KN',
#    'FEATS': '_',
#    'HEAD': '14',
#    'DEPREL': 'cc',
#    'DEPS': '14:cc',
#    'MISC': '_'},
#   '13': {'ID': '13',
#    'FORM': 'kommunal',
#    'LEMMA': 'kommunal',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Degree=Pos|Gender=Com|Number=Sing',
#    'HEAD': '14',
#    'DEPREL': 'amod',
#    'DEPS': '14:amod',
#    'MISC': '_'},
#   '14': {'ID': '14',
#    'FORM': 'förtroendeman',
#    'LEMMA': 'förtroendeman',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '9',
#    'DEPREL': 'conj',
#    'DEPS': '7:nmod:från|9:conj:eller',
#    'MISC': 'SpaceAfter=No'},
#   '15': {'ID': '15',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '5',
#    'DEPREL': 'punct',
#    'DEPS': '5:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Det',
#    'LEMMA': 'den',
#    'UPOS': 'PRON',
#    'XPOS': 'PN|NEU|SIN|DEF|SUB/OBJ',
#    'FEATS': 'Definite=Def|Gender=Neut|Number=Sing|PronType=Prs',
#    'HEAD': '2',
#    'DEPREL': 'expl',
#    'DEPS': '2:expl',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'räcker',
#    'LEMMA': 'räcka',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'med',
#    'LEMMA': 'med',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '10',
#    'DEPREL': 'mark',
#    'DEPS': '10:mark',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'att',
#    'LEMMA': 'att',
#    'UPOS': 'SCONJ',
#    'XPOS': 'SN',
#    'FEATS': '_',
#    'HEAD': '10',
#    'DEPREL': 'mark',
#    'DEPS': '10:mark',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'intyg',
#    'LEMMA': 'intyg',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '10',
#    'DEPREL': 'nsubj:pass',
#    'DEPS': '10:nsubj:pass',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'eller',
#    'LEMMA': 'eller',
#    'UPOS': 'CCONJ',
#    'XPOS': 'KN',
#    'FEATS': '_',
#    'HEAD': '9',
#    'DEPREL': 'cc',
#    'DEPS': '9:cc',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'annat',
#    'LEMMA': 'annan',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Degree=Pos|Gender=Neut|Number=Sing',
#    'HEAD': '9',
#    'DEPREL': 'amod',
#    'DEPS': '9:amod',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'skriftligt',
#    'LEMMA': 'skriftlig',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Degree=Pos|Gender=Neut|Number=Sing',
#    'HEAD': '9',
#    'DEPREL': 'amod',
#    'DEPS': '9:amod',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': 'bevis',
#    'LEMMA': 'bevis',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '5',
#    'DEPREL': 'conj',
#    'DEPS': '5:conj:eller|10:nsubj:pass',
#    'MISC': '_'},
#   '10': {'ID': '10',
#    'FORM': 'bifogas',
#    'LEMMA': 'bifoga',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|SFO',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Pass',
#    'HEAD': '2',
#    'DEPREL': 'advcl',
#    'DEPS': '2:advcl:att',
#    'MISC': '_'},
#   '11': {'ID': '11',
#    'FORM': 'deklarationen',
#    'LEMMA': 'deklaration',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Sing',
#    'HEAD': '10',
#    'DEPREL': 'obj',
#    'DEPS': '10:obj',
#    'MISC': 'SpaceAfter=No'},
#   '12': {'ID': '12',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '2',
#    'DEPREL': 'punct',
#    'DEPS': '2:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Som',
#    'LEMMA': 'som',
#    'UPOS': 'SCONJ',
#    'XPOS': 'KN',
#    'FEATS': '_',
#    'HEAD': '2',
#    'DEPREL': 'mark',
#    'DEPS': '2:mark',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'bevis',
#    'LEMMA': 'bevis',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '4',
#    'DEPREL': 'xcomp',
#    'DEPS': '4:xcomp',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'torde',
#    'LEMMA': 'torde',
#    'UPOS': 'AUX',
#    'XPOS': 'VB|PRT|AKT',
#    'FEATS': 'Mood=Ind|Tense=Past|VerbForm=Fin|Voice=Act',
#    'HEAD': '4',
#    'DEPREL': 'aux',
#    'DEPS': '4:aux',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'godtas',
#    'LEMMA': 'godta',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|INF|SFO',
#    'FEATS': 'VerbForm=Inf|Voice=Pass',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'dom',
#    'LEMMA': 'dom',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '4',
#    'DEPREL': 'nsubj:pass',
#    'DEPS': '2:nsubj|4:nsubj:pass',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'eller',
#    'LEMMA': 'eller',
#    'UPOS': 'CCONJ',
#    'XPOS': 'KN',
#    'FEATS': '_',
#    'HEAD': '7',
#    'DEPREL': 'cc',
#    'DEPS': '7:cc',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'avtal',
#    'LEMMA': 'avtal',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '5',
#    'DEPREL': 'conj',
#    'DEPS': '2:nsubj|4:nsubj:pass|5:conj:eller',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'om',
#    'LEMMA': 'om',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '9',
#    'DEPREL': 'case',
#    'DEPS': '9:case',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': 'underhållsskyldighet',
#    'LEMMA': 'underhållsskyldighet',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '7',
#    'DEPREL': 'nmod',
#    'DEPS': '7:nmod:om',
#    'MISC': '_'},
#   '10': {'ID': '10',
#    'FORM': 'jämte',
#    'LEMMA': 'jämte',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '11',
#    'DEPREL': 'case',
#    'DEPS': '11:case',
#    'MISC': '_'},
#   '11': {'ID': '11',
#    'FORM': 'kvitto',
#    'LEMMA': 'kvitto',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '7',
#    'DEPREL': 'nmod',
#    'DEPS': '7:nmod:jämte',
#    'MISC': '_'},
#   '12': {'ID': '12',
#    'FORM': 'på',
#    'LEMMA': 'på',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '14',
#    'DEPREL': 'case',
#    'DEPS': '14:case',
#    'MISC': '_'},
#   '13': {'ID': '13',
#    'FORM': 'betalt',
#    'LEMMA': 'betala',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRF|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing|Tense=Past|VerbForm=Part',
#    'HEAD': '14',
#    'DEPREL': 'amod',
#    'DEPS': '14:amod',
#    'MISC': '_'},
#   '14': {'ID': '14',
#    'FORM': 'belopp',
#    'LEMMA': 'belopp',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '11',
#    'DEPREL': 'nmod',
#    'DEPS': '11:nmod:på',
#    'MISC': '_'},
#   '15': {'ID': '15',
#    'FORM': 'eller',
#    'LEMMA': 'eller',
#    'UPOS': 'CCONJ',
#    'XPOS': 'KN',
#    'FEATS': '_',
#    'HEAD': '16',
#    'DEPREL': 'cc',
#    'DEPS': '16:cc',
#    'MISC': '_'},
#   '16': {'ID': '16',
#    'FORM': 'intyg',
#    'LEMMA': 'intyg',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '11',
#    'DEPREL': 'conj',
#    'DEPS': '7:nmod:jämte|11:conj:eller',
#    'MISC': '_'},
#   '17': {'ID': '17',
#    'FORM': 'från',
#    'LEMMA': 'från',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '19',
#    'DEPREL': 'case',
#    'DEPS': '19:case',
#    'MISC': '_'},
#   '18': {'ID': '18',
#    'FORM': 'trovärdig',
#    'LEMMA': 'trovärdig',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Degree=Pos|Gender=Com|Number=Sing',
#    'HEAD': '19',
#    'DEPREL': 'amod',
#    'DEPS': '19:amod',
#    'MISC': '_'},
#   '19': {'ID': '19',
#    'FORM': 'person',
#    'LEMMA': 'person',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '16',
#    'DEPREL': 'nmod',
#    'DEPS': '16:nmod:från',
#    'MISC': 'SpaceAfter=No'},
#   '20': {'ID': '20',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '4',
#    'DEPREL': 'punct',
#    'DEPS': '4:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Ortsavdraget',
#    'LEMMA': 'ortsavdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Neut|Number=Sing',
#    'HEAD': '2',
#    'DEPREL': 'nsubj:pass',
#    'DEPS': '2:nsubj:pass',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'ersätts',
#    'LEMMA': 'ersätta',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|SFO',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Pass',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'med',
#    'LEMMA': 'med',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '4',
#    'DEPREL': 'case',
#    'DEPS': '4:case',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'grundavdrag',
#    'LEMMA': 'grundavdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '2',
#    'DEPREL': 'obl',
#    'DEPS': '2:obl:med',
#    'MISC': 'SpaceAfter=No'},
#   '5': {'ID': '5',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '2',
#    'DEPREL': 'punct',
#    'DEPS': '2:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Det',
#    'LEMMA': 'en',
#    'UPOS': 'DET',
#    'XPOS': 'DT|NEU|SIN|DEF',
#    'FEATS': 'Definite=Def|Gender=Neut|Number=Sing|PronType=Art',
#    'HEAD': '3',
#    'DEPREL': 'det',
#    'DEPS': '3:det',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'nya',
#    'LEMMA': 'ny',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR/NEU|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Degree=Pos|Number=Sing',
#    'HEAD': '3',
#    'DEPREL': 'amod',
#    'DEPS': '3:amod',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'grundavdraget',
#    'LEMMA': 'grundavdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Neut|Number=Sing',
#    'HEAD': '10',
#    'DEPREL': 'nsubj',
#    'DEPS': '6:nsubj|10:nsubj',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': '-',
#    'LEMMA': '-',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MID',
#    'FEATS': '_',
#    'HEAD': '3',
#    'DEPREL': 'punct',
#    'DEPS': '3:punct',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'som',
#    'LEMMA': 'som',
#    'UPOS': 'PRON',
#    'XPOS': 'HP|-|-|-',
#    'FEATS': 'PronType=Rel',
#    'HEAD': '6',
#    'DEPREL': 'nsubj',
#    'DEPS': '3:ref',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'ersätter',
#    'LEMMA': 'ersätta',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '3',
#    'DEPREL': 'acl:relcl',
#    'DEPS': '3:acl:relcl',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'tidigare',
#    'LEMMA': 'tidig',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|KOM|UTR/NEU|SIN/PLU|IND/DEF|NOM',
#    'FEATS': 'Case=Nom|Degree=Cmp',
#    'HEAD': '8',
#    'DEPREL': 'amod',
#    'DEPS': '8:amod',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'ortsavdrag',
#    'LEMMA': 'ortsavdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|PLU|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Plur',
#    'HEAD': '6',
#    'DEPREL': 'obj',
#    'DEPS': '6:obj',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': '-',
#    'LEMMA': '-',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MID',
#    'FEATS': '_',
#    'HEAD': '3',
#    'DEPREL': 'punct',
#    'DEPS': '3:punct',
#    'MISC': '_'},
#   '10': {'ID': '10',
#    'FORM': 'uppgår',
#    'LEMMA': 'uppgå',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '11': {'ID': '11',
#    'FORM': 'till',
#    'LEMMA': 'till',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '13',
#    'DEPREL': 'case',
#    'DEPS': '13:case',
#    'MISC': '_'},
#   '12': {'ID': '12',
#    'FORM': '4500',
#    'LEMMA': '4500',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '13',
#    'DEPREL': 'nummod',
#    'DEPS': '13:nummod',
#    'MISC': '_'},
#   '13': {'ID': '13',
#    'FORM': 'kr',
#    'LEMMA': 'kr',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|AN',
#    'FEATS': 'Abbr=Yes',
#    'HEAD': '10',
#    'DEPREL': 'obl',
#    'DEPS': '10:obl:till',
#    'MISC': '_'},
#   '14': {'ID': '14',
#    'FORM': 'för',
#    'LEMMA': 'för',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '16',
#    'DEPREL': 'case',
#    'DEPS': '16:case',
#    'MISC': '_'},
#   '15': {'ID': '15',
#    'FORM': 'varje',
#    'LEMMA': 'varje',
#    'UPOS': 'DET',
#    'XPOS': 'DT|UTR/NEU|SIN|IND',
#    'FEATS': 'Definite=Ind|Number=Sing|PronType=Tot',
#    'HEAD': '16',
#    'DEPREL': 'det',
#    'DEPS': '16:det',
#    'MISC': '_'},
#   '16': {'ID': '16',
#    'FORM': 'skattskyldig',
#    'LEMMA': 'skattskyldig',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Degree=Pos|Gender=Com|Number=Sing',
#    'HEAD': '10',
#    'DEPREL': 'advmod',
#    'DEPS': '10:advmod',
#    'MISC': '_'},
#   '17': {'ID': '17',
#    'FORM': 'med',
#    'LEMMA': 'med',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '23',
#    'DEPREL': 'case',
#    'DEPS': '23:case',
#    'MISC': '_'},
#   '18': {'ID': '18',
#    'FORM': 'en',
#    'LEMMA': 'en',
#    'UPOS': 'DET',
#    'XPOS': 'DT|UTR|SIN|IND',
#    'FEATS': 'Definite=Ind|Gender=Com|Number=Sing|PronType=Art',
#    'HEAD': '23',
#    'DEPREL': 'det',
#    'DEPS': '23:det',
#    'MISC': '_'},
#   '19': {'ID': '19',
#    'FORM': 'till',
#    'LEMMA': 'till',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '21',
#    'DEPREL': 'case',
#    'DEPS': '21:case',
#    'MISC': '_'},
#   '20': {'ID': '20',
#    'FORM': 'statlig',
#    'LEMMA': 'statlig',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Degree=Pos|Gender=Com|Number=Sing',
#    'HEAD': '21',
#    'DEPREL': 'amod',
#    'DEPS': '21:amod',
#    'MISC': '_'},
#   '21': {'ID': '21',
#    'FORM': 'inkomstskatt',
#    'LEMMA': 'inkomstskatt',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '22',
#    'DEPREL': 'obl',
#    'DEPS': '22:obl:till',
#    'MISC': '_'},
#   '22': {'ID': '22',
#    'FORM': 'taxerad',
#    'LEMMA': 'taxera',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRF|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing|Tense=Past|VerbForm=Part',
#    'HEAD': '23',
#    'DEPREL': 'amod',
#    'DEPS': '23:amod',
#    'MISC': '_'},
#   '23': {'ID': '23',
#    'FORM': 'inkomst',
#    'LEMMA': 'inkomst',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '16',
#    'DEPREL': 'nmod',
#    'DEPS': '16:nmod:med',
#    'MISC': '_'},
#   '24': {'ID': '24',
#    'FORM': 'av',
#    'LEMMA': 'av',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '27',
#    'DEPREL': 'case',
#    'DEPS': '27:case',
#    'MISC': '_'},
#   '25': {'ID': '25',
#    'FORM': 'högst',
#    'LEMMA': 'hög',
#    'UPOS': 'ADV',
#    'XPOS': 'AB|SUV',
#    'FEATS': 'Degree=Sup',
#    'HEAD': '26',
#    'DEPREL': 'advmod',
#    'DEPS': '26:advmod',
#    'MISC': '_'},
#   '26': {'ID': '26',
#    'FORM': '30000',
#    'LEMMA': '30000',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '27',
#    'DEPREL': 'nummod',
#    'DEPS': '27:nummod',
#    'MISC': '_'},
#   '27': {'ID': '27',
#    'FORM': 'kr',
#    'LEMMA': 'kr',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|AN',
#    'FEATS': 'Abbr=Yes',
#    'HEAD': '23',
#    'DEPREL': 'nmod',
#    'DEPS': '23:nmod:av',
#    'MISC': 'SpaceAfter=No'},
#   '28': {'ID': '28',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '10',
#    'DEPREL': 'punct',
#    'DEPS': '10:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Vid',
#    'LEMMA': 'vid',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '4',
#    'DEPREL': 'case',
#    'DEPS': '4:case',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'högre',
#    'LEMMA': 'hög',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|KOM|UTR/NEU|SIN/PLU|IND/DEF|NOM',
#    'FEATS': 'Case=Nom|Degree=Cmp',
#    'HEAD': '4',
#    'DEPREL': 'amod',
#    'DEPS': '4:amod',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'taxerad',
#    'LEMMA': 'taxera',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRF|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing|Tense=Past|VerbForm=Part',
#    'HEAD': '4',
#    'DEPREL': 'amod',
#    'DEPS': '4:amod',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'inkomst',
#    'LEMMA': 'inkomst',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '5',
#    'DEPREL': 'obl',
#    'DEPS': '5:obl:vid',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'sjunker',
#    'LEMMA': 'sjunka',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'avdraget',
#    'LEMMA': 'avdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Neut|Number=Sing',
#    'HEAD': '5',
#    'DEPREL': 'nsubj',
#    'DEPS': '5:nsubj',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'med',
#    'LEMMA': 'med',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '9',
#    'DEPREL': 'case',
#    'DEPS': '9:case',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'en',
#    'LEMMA': 'en',
#    'UPOS': 'DET',
#    'XPOS': 'DT|UTR|SIN|IND',
#    'FEATS': 'Definite=Ind|Gender=Com|Number=Sing|PronType=Art',
#    'HEAD': '9',
#    'DEPREL': 'det',
#    'DEPS': '9:det',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': 'femtedel',
#    'LEMMA': 'femtedel',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '5',
#    'DEPREL': 'obl',
#    'DEPS': '5:obl:med',
#    'MISC': '_'},
#   '10': {'ID': '10',
#    'FORM': 'av',
#    'LEMMA': 'av',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '12',
#    'DEPREL': 'case',
#    'DEPS': '12:case',
#    'MISC': '_'},
#   '11': {'ID': '11',
#    'FORM': 'det',
#    'LEMMA': 'en',
#    'UPOS': 'DET',
#    'XPOS': 'DT|NEU|SIN|DEF',
#    'FEATS': 'Definite=Def|Gender=Neut|Number=Sing|PronType=Art',
#    'HEAD': '12',
#    'DEPREL': 'det',
#    'DEPS': '12:det',
#    'MISC': '_'},
#   '12': {'ID': '12',
#    'FORM': 'belopp',
#    'LEMMA': 'belopp',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '9',
#    'DEPREL': 'nmod',
#    'DEPS': '9:nmod:av|14:nsubj',
#    'MISC': '_'},
#   '13': {'ID': '13',
#    'FORM': 'som',
#    'LEMMA': 'som',
#    'UPOS': 'PRON',
#    'XPOS': 'HP|-|-|-',
#    'FEATS': 'PronType=Rel',
#    'HEAD': '14',
#    'DEPREL': 'nsubj',
#    'DEPS': '12:ref',
#    'MISC': '_'},
#   '14': {'ID': '14',
#    'FORM': 'överstiger',
#    'LEMMA': 'överstiga',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '12',
#    'DEPREL': 'acl:relcl',
#    'DEPS': '12:acl:relcl',
#    'MISC': '_'},
#   '15': {'ID': '15',
#    'FORM': '30000',
#    'LEMMA': '30000',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '16',
#    'DEPREL': 'nummod',
#    'DEPS': '16:nummod',
#    'MISC': '_'},
#   '16': {'ID': '16',
#    'FORM': 'kronor',
#    'LEMMA': 'krona',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|PLU|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Plur',
#    'HEAD': '14',
#    'DEPREL': 'obj',
#    'DEPS': '14:obj',
#    'MISC': 'SpaceAfter=No'},
#   '17': {'ID': '17',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '5',
#    'DEPREL': 'punct',
#    'DEPS': '5:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Grundavdraget',
#    'LEMMA': 'grundavdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Neut|Number=Sing',
#    'HEAD': '2',
#    'DEPREL': 'nsubj',
#    'DEPS': '2:nsubj',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'upphör',
#    'LEMMA': 'upphöra',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'alltså',
#    'LEMMA': 'alltså',
#    'UPOS': 'ADV',
#    'XPOS': 'AB',
#    'FEATS': '_',
#    'HEAD': '2',
#    'DEPREL': 'advmod',
#    'DEPS': '2:advmod',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'vid',
#    'LEMMA': 'vid',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '7',
#    'DEPREL': 'case',
#    'DEPS': '7:case',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'en',
#    'LEMMA': 'en',
#    'UPOS': 'DET',
#    'XPOS': 'DT|UTR|SIN|IND',
#    'FEATS': 'Definite=Ind|Gender=Com|Number=Sing|PronType=Art',
#    'HEAD': '7',
#    'DEPREL': 'det',
#    'DEPS': '7:det',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'taxerad',
#    'LEMMA': 'taxera',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRF|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing|Tense=Past|VerbForm=Part',
#    'HEAD': '7',
#    'DEPREL': 'amod',
#    'DEPS': '7:amod',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'inkomst',
#    'LEMMA': 'inkomst',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '2',
#    'DEPREL': 'obl',
#    'DEPS': '2:obl:vid',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'på',
#    'LEMMA': 'på',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '10',
#    'DEPREL': 'case',
#    'DEPS': '10:case',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': '52500',
#    'LEMMA': '52500',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '10',
#    'DEPREL': 'nummod',
#    'DEPS': '10:nummod',
#    'MISC': '_'},
#   '10': {'ID': '10',
#    'FORM': 'kr',
#    'LEMMA': 'kr',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|AN',
#    'FEATS': 'Abbr=Yes',
#    'HEAD': '7',
#    'DEPREL': 'nmod',
#    'DEPS': '7:nmod:på',
#    'MISC': 'SpaceAfter=No'},
#   '11': {'ID': '11',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '2',
#    'DEPREL': 'punct',
#    'DEPS': '2:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Exempel',
#    'LEMMA': 'exempel',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': 'SpaceAfter=No'},
#   '2': {'ID': '2',
#    'FORM': ':',
#    'LEMMA': ':',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '1',
#    'DEPREL': 'punct',
#    'DEPS': '1:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Statligt',
#    'LEMMA': 'statlig',
#    'UPOS': 'ADV',
#    'XPOS': 'AB|POS',
#    'FEATS': 'Degree=Pos',
#    'HEAD': '2',
#    'DEPREL': 'advmod',
#    'DEPS': '2:advmod',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'taxerad',
#    'LEMMA': 'taxera',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRF|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing|Tense=Past|VerbForm=Part',
#    'HEAD': '3',
#    'DEPREL': 'amod',
#    'DEPS': '3:amod',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'inkomst',
#    'LEMMA': 'inkomst',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '4',
#    'DEPREL': 'nsubj',
#    'DEPS': '4:nsubj',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'uppgår',
#    'LEMMA': 'uppgå',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'till',
#    'LEMMA': 'till',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '7',
#    'DEPREL': 'case',
#    'DEPS': '7:case',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': '40000',
#    'LEMMA': '40000',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
# ...
#    'UPOS': 'AUX',
#    'XPOS': 'VB|INF|AKT',
#    'FEATS': 'VerbForm=Inf|Voice=Act',
#    'HEAD': '8',
#    'DEPREL': 'aux',
#    'DEPS': '8:aux',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'ha',
#    'LEMMA': 'ha',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|INF|AKT',
#    'FEATS': 'VerbForm=Inf|Voice=Act',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': 'en',
#    'LEMMA': 'en',
#    'UPOS': 'DET',
#    'XPOS': 'DT|UTR|SIN|IND',
#    'FEATS': 'Definite=Ind|Gender=Com|Number=Sing|PronType=Art',
#    'HEAD': '10',
#    'DEPREL': 'det',
#    'DEPS': '10:det',
#    'MISC': '_'},
#   '10': {'ID': '10',
#    'FORM': 'inkomst',
#    'LEMMA': 'inkomst',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '8',
#    'DEPREL': 'obj',
#    'DEPS': '8:obj',
#    'MISC': '_'},
#   '11': {'ID': '11',
#    'FORM': 'om',
#    'LEMMA': 'om',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '13',
#    'DEPREL': 'case',
#    'DEPS': '13:case',
#    'MISC': '_'},
#   '12': {'ID': '12',
#    'FORM': '1500',
#    'LEMMA': '1500',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '13',
#    'DEPREL': 'nummod',
#    'DEPS': '13:nummod',
#    'MISC': '_'},
#   '13': {'ID': '13',
#    'FORM': 'kr',
#    'LEMMA': 'kr',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|AN',
#    'FEATS': 'Abbr=Yes',
#    'HEAD': '10',
#    'DEPREL': 'nmod',
#    'DEPS': '10:nmod:om',
#    'MISC': '_'},
#   '14': {'ID': '14',
#    'FORM': 'vid',
#    'LEMMA': 'vid',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '17',
#    'DEPREL': 'case',
#    'DEPS': '17:case',
#    'MISC': '_'},
#   '15': {'ID': '15',
#    'FORM': 'sidan',
#    'LEMMA': 'sida',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Sing',
#    'HEAD': '14',
#    'DEPREL': 'fixed',
#    'DEPS': '14:fixed',
#    'MISC': '_'},
#   '16': {'ID': '16',
#    'FORM': 'av',
#    'LEMMA': 'av',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '14',
#    'DEPREL': 'fixed',
#    'DEPS': '14:fixed',
#    'MISC': '_'},
#   '17': {'ID': '17',
#    'FORM': 'folkpensionen',
#    'LEMMA': 'folkpension',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Sing',
#    'HEAD': '8',
#    'DEPREL': 'obl',
#    'DEPS': '8:obl:vid_sidan_av',
#    'MISC': '_'},
#   '18': {'ID': '18',
#    'FORM': 'och',
#    'LEMMA': 'och',
#    'UPOS': 'CCONJ',
#    'XPOS': 'KN',
#    'FEATS': '_',
#    'HEAD': '20',
#    'DEPREL': 'cc',
#    'DEPS': '20:cc',
#    'MISC': '_'},
#   '19': {'ID': '19',
#    'FORM': 'ändock',
#    'LEMMA': 'ändock',
#    'UPOS': 'ADV',
#    'XPOS': 'AB',
#    'FEATS': '_',
#    'HEAD': '20',
#    'DEPREL': 'advmod',
#    'DEPS': '20:advmod',
#    'MISC': '_'},
#   '20': {'ID': '20',
#    'FORM': 'bli',
#    'LEMMA': 'bli',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|INF|AKT',
#    'FEATS': 'VerbForm=Inf|Voice=Act',
#    'HEAD': '8',
#    'DEPREL': 'conj',
#    'DEPS': '8:conj:och',
#    'MISC': '_'},
#   '21': {'ID': '21',
#    'FORM': 'skattefri',
#    'LEMMA': 'skattefri',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Degree=Pos|Gender=Com|Number=Sing',
#    'HEAD': '20',
#    'DEPREL': 'xcomp',
#    'DEPS': '20:xcomp',
#    'MISC': 'SpaceAfter=No'},
#   '22': {'ID': '22',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '8',
#    'DEPREL': 'punct',
#    'DEPS': '8:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Gifta',
#    'LEMMA': 'gift',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRF|UTR/NEU|PLU|IND/DEF|NOM',
#    'FEATS': 'Case=Nom|Number=Plur|Tense=Past|VerbForm=Part',
#    'HEAD': '2',
#    'DEPREL': 'amod',
#    'DEPS': '2:amod',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'pensionärer',
#    'LEMMA': 'pensionär',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|PLU|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Plur',
#    'HEAD': '3',
#    'DEPREL': 'nsubj',
#    'DEPS': '3:nsubj|4:nsubj',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'blir',
#    'LEMMA': 'bli',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'skattefria',
#    'LEMMA': 'skattefri',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR/NEU|PLU|IND/DEF|NOM',
#    'FEATS': 'Case=Nom|Degree=Pos|Number=Plur',
#    'HEAD': '3',
#    'DEPREL': 'xcomp',
#    'DEPS': '3:xcomp',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'om',
#    'LEMMA': 'om',
#    'UPOS': 'SCONJ',
#    'XPOS': 'SN',
#    'FEATS': '_',
#    'HEAD': '7',
#    'DEPREL': 'mark',
#    'DEPS': '7:mark',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'sidoinkomsten',
#    'LEMMA': 'sidoinkomst',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Sing',
#    'HEAD': '7',
#    'DEPREL': 'nsubj',
#    'DEPS': '7:nsubj',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'uppgår',
#    'LEMMA': 'uppgå',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|AKT',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act',
#    'HEAD': '3',
#    'DEPREL': 'advcl',
#    'DEPS': '3:advcl:om',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'till',
#    'LEMMA': 'till',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '11',
#    'DEPREL': 'case',
#    'DEPS': '11:case',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': 'högst',
#    'LEMMA': 'hög',
#    'UPOS': 'ADV',
#    'XPOS': 'AB|SUV',
#    'FEATS': 'Degree=Sup',
#    'HEAD': '10',
#    'DEPREL': 'advmod',
#    'DEPS': '10:advmod',
#    'MISC': '_'},
#   '10': {'ID': '10',
#    'FORM': '2000',
#    'LEMMA': '2000',
#    'UPOS': 'NUM',
#    'XPOS': 'RG|NOM',
#    'FEATS': 'Case=Nom|NumType=Card',
#    'HEAD': '11',
#    'DEPREL': 'nummod',
#    'DEPS': '11:nummod',
#    'MISC': '_'},
#   '11': {'ID': '11',
#    'FORM': 'kr',
#    'LEMMA': 'kr',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|AN',
#    'FEATS': 'Abbr=Yes',
#    'HEAD': '7',
#    'DEPREL': 'obl',
#    'DEPS': '7:obl:till',
#    'MISC': '_'},
#   '12': {'ID': '12',
#    'FORM': 'för',
#    'LEMMA': 'för',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '13',
#    'DEPREL': 'case',
#    'DEPS': '13:case',
#    'MISC': '_'},
#   '13': {'ID': '13',
#    'FORM': 'makarna',
#    'LEMMA': 'make',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|PLU|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Plur',
#    'HEAD': '7',
#    'DEPREL': 'obl',
#    'DEPS': '7:obl:för',
#    'MISC': '_'},
#   '14': {'ID': '14',
#    'FORM': 'tillsammans',
#    'LEMMA': 'tillsammans',
#    'UPOS': 'ADV',
#    'XPOS': 'AB',
#    'FEATS': '_',
#    'HEAD': '13',
#    'DEPREL': 'nmod',
#    'DEPS': '13:nmod',
#    'MISC': 'SpaceAfter=No'},
#   '15': {'ID': '15',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '3',
#    'DEPREL': 'punct',
#    'DEPS': '3:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Tekniskt',
#    'LEMMA': 'teknisk',
#    'UPOS': 'ADV',
#    'XPOS': 'AB|POS',
#    'FEATS': 'Degree=Pos',
#    'HEAD': '2',
#    'DEPREL': 'advmod',
#    'DEPS': '2:advmod',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'ordnas',
#    'LEMMA': 'ordna',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRS|SFO',
#    'FEATS': 'Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Pass',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'detta',
#    'LEMMA': 'denna',
#    'UPOS': 'PRON',
#    'XPOS': 'PN|NEU|SIN|DEF|SUB/OBJ',
#    'FEATS': 'Definite=Def|Gender=Neut|Number=Sing|PronType=Dem',
#    'HEAD': '2',
#    'DEPREL': 'nsubj:pass',
#    'DEPS': '2:nsubj:pass',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'genom',
#    'LEMMA': 'genom',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '7',
#    'DEPREL': 'case',
#    'DEPS': '7:case',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'ett',
#    'LEMMA': 'en',
#    'UPOS': 'DET',
#    'XPOS': 'DT|NEU|SIN|IND',
#    'FEATS': 'Definite=Ind|Gender=Neut|Number=Sing|PronType=Art',
#    'HEAD': '7',
#    'DEPREL': 'det',
#    'DEPS': '7:det',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'extra',
#    'LEMMA': 'extra',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR/NEU|SIN/PLU|IND/DEF|NOM',
#    'FEATS': 'Case=Nom|Degree=Pos',
#    'HEAD': '7',
#    'DEPREL': 'amod',
#    'DEPS': '7:amod',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'avdrag',
#    'LEMMA': 'avdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '2',
#    'DEPREL': 'obl',
#    'DEPS': '2:obl:genom',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'utöver',
#    'LEMMA': 'utöver',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '9',
#    'DEPREL': 'case',
#    'DEPS': '9:case',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': 'grundavdraget',
#    'LEMMA': 'grundavdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Neut|Number=Sing',
#    'HEAD': '7',
#    'DEPREL': 'nmod',
#    'DEPS': '7:nmod:utöver',
#    'MISC': 'SpaceAfter=No'},
#   '10': {'ID': '10',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '2',
#    'DEPREL': 'punct',
#    'DEPS': '2:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'För',
#    'LEMMA': 'för',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '3',
#    'DEPREL': 'mark',
#    'DEPS': '3:mark',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'att',
#    'LEMMA': 'att',
#    'UPOS': 'PART',
#    'XPOS': 'IE',
#    'FEATS': '_',
#    'HEAD': '3',
#    'DEPREL': 'mark',
#    'DEPS': '3:mark',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'belysa',
#    'LEMMA': 'belysa',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|INF|AKT',
#    'FEATS': 'VerbForm=Inf|Voice=Act',
#    'HEAD': '15',
#    'DEPREL': 'advcl',
#    'DEPS': '15:advcl:att',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'verkningarna',
#    'LEMMA': 'verkning',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|PLU|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Plur',
#    'HEAD': '3',
#    'DEPREL': 'obj',
#    'DEPS': '3:obj',
#    'MISC': '_'},
#   '5': {'ID': '5',
#    'FORM': 'för',
#    'LEMMA': 'för',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '6',
#    'DEPREL': 'case',
#    'DEPS': '6:case',
#    'MISC': '_'},
#   '6': {'ID': '6',
#    'FORM': 'folkpensionärerna',
#    'LEMMA': 'folkpensionär',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|PLU|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Plur',
#    'HEAD': '4',
#    'DEPREL': 'nmod',
#    'DEPS': '4:nmod:för',
#    'MISC': '_'},
#   '7': {'ID': '7',
#    'FORM': 'av',
#    'LEMMA': 'av',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '10',
#    'DEPREL': 'case',
#    'DEPS': '10:case',
#    'MISC': '_'},
#   '8': {'ID': '8',
#    'FORM': 'det',
#    'LEMMA': 'en',
#    'UPOS': 'DET',
#    'XPOS': 'DT|NEU|SIN|DEF',
#    'FEATS': 'Definite=Def|Gender=Neut|Number=Sing|PronType=Art',
#    'HEAD': '10',
#    'DEPREL': 'det',
#    'DEPS': '10:det',
#    'MISC': '_'},
#   '9': {'ID': '9',
#    'FORM': 'nya',
#    'LEMMA': 'ny',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR/NEU|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Degree=Pos|Number=Sing',
#    'HEAD': '10',
#    'DEPREL': 'amod',
#    'DEPS': '10:amod',
#    'MISC': '_'},
#   '10': {'ID': '10',
#    'FORM': 'systemet',
#    'LEMMA': 'system',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Neut|Number=Sing',
#    'HEAD': '4',
#    'DEPREL': 'nmod',
#    'DEPS': '4:nmod:av',
#    'MISC': '_'},
#   '11': {'ID': '11',
#    'FORM': 'att',
#    'LEMMA': 'att',
#    'UPOS': 'PART',
#    'XPOS': 'IE',
#    'FEATS': '_',
#    'HEAD': '12',
#    'DEPREL': 'mark',
#    'DEPS': '12:mark',
#    'MISC': '_'},
#   '12': {'ID': '12',
#    'FORM': 'beräkna',
#    'LEMMA': 'beräkna',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|INF|AKT',
#    'FEATS': 'VerbForm=Inf|Voice=Act',
#    'HEAD': '10',
#    'DEPREL': 'acl',
#    'DEPS': '10:acl:att',
#    'MISC': '_'},
#   '13': {'ID': '13',
#    'FORM': 'extra',
#    'LEMMA': 'extra',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR/NEU|SIN/PLU|IND/DEF|NOM',
#    'FEATS': 'Case=Nom|Degree=Pos',
#    'HEAD': '14',
#    'DEPREL': 'amod',
#    'DEPS': '14:amod',
#    'MISC': '_'},
#   '14': {'ID': '14',
#    'FORM': 'avdrag',
#    'LEMMA': 'avdrag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|NEU|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Neut|Number=Sing',
#    'HEAD': '12',
#    'DEPREL': 'obj',
#    'DEPS': '12:obj',
#    'MISC': '_'},
#   '15': {'ID': '15',
#    'FORM': 'åberopade',
#    'LEMMA': 'åberopa',
#    'UPOS': 'VERB',
#    'XPOS': 'VB|PRT|AKT',
#    'FEATS': 'Mood=Ind|Tense=Past|VerbForm=Fin|Voice=Act',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '16': {'ID': '16',
#    'FORM': 'finansministern',
#    'LEMMA': 'finansminister',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Sing',
#    'HEAD': '15',
#    'DEPREL': 'nsubj',
#    'DEPS': '15:nsubj',
#    'MISC': '_'},
#   '17': {'ID': '17',
#    'FORM': 'i',
#    'LEMMA': 'i',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '18',
#    'DEPREL': 'case',
#    'DEPS': '18:case',
#    'MISC': '_'},
#   '18': {'ID': '18',
#    'FORM': 'propositionen',
#    'LEMMA': 'proposition',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Sing',
#    'HEAD': '15',
#    'DEPREL': 'obl',
#    'DEPS': '15:obl:i',
#    'MISC': '_'},
#   '19': {'ID': '19',
#    'FORM': 'till',
#    'LEMMA': 'till',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '20',
#    'DEPREL': 'case',
#    'DEPS': '20:case',
#    'MISC': '_'},
#   '20': {'ID': '20',
#    'FORM': 'riksdagen',
#    'LEMMA': 'riksdag',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|DEF|NOM',
#    'FEATS': 'Case=Nom|Definite=Def|Gender=Com|Number=Sing',
#    'HEAD': '18',
#    'DEPREL': 'nmod',
#    'DEPS': '18:nmod:till',
#    'MISC': '_'},
#   '21': {'ID': '21',
#    'FORM': 'följande',
#    'LEMMA': 'följande',
#    'UPOS': 'ADJ',
#    'XPOS': 'PC|PRS|UTR/NEU|SIN/PLU|IND/DEF|NOM',
#    'FEATS': 'Case=Nom|Tense=Pres|VerbForm=Part',
#    'HEAD': '22',
#    'DEPREL': 'amod',
#    'DEPS': '22:amod',
#    'MISC': '_'},
#   '22': {'ID': '22',
#    'FORM': 'tabell',
#    'LEMMA': 'tabell',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '15',
#    'DEPREL': 'obj',
#    'DEPS': '15:obj',
#    'MISC': 'SpaceAfter=No'},
#   '23': {'ID': '23',
#    'FORM': '.',
#    'LEMMA': '.',
#    'UPOS': 'PUNCT',
#    'XPOS': 'MAD',
#    'FEATS': '_',
#    'HEAD': '15',
#    'DEPREL': 'punct',
#    'DEPS': '15:punct',
#    'MISC': '_'}},
#  {'0': {'ID': '0',
#    'FORM': 'ROOT',
#    'LEMMA': 'ROOT',
#    'UPOS': 'ROOT',
#    'XPOS': 'ROOT',
#    'FEATS': 'ROOT',
#    'HEAD': '0',
#    'DEPREL': 'ROOT',
#    'DEPS': '0',
#    'MISC': 'ROOT'},
#   '1': {'ID': '1',
#    'FORM': 'Från',
#    'LEMMA': 'från',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '2',
#    'DEPREL': 'case',
#    'DEPS': '2:case',
#    'MISC': '_'},
#   '2': {'ID': '2',
#    'FORM': 'civil',
#    'LEMMA': 'civil',
#    'UPOS': 'ADJ',
#    'XPOS': 'JJ|POS|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Degree=Pos|Gender=Com|Number=Sing',
#    'HEAD': '0',
#    'DEPREL': 'root',
#    'DEPS': '0:root',
#    'MISC': '_'},
#   '3': {'ID': '3',
#    'FORM': 'till',
#    'LEMMA': 'till',
#    'UPOS': 'ADP',
#    'XPOS': 'PP',
#    'FEATS': '_',
#    'HEAD': '4',
#    'DEPREL': 'case',
#    'DEPS': '4:case',
#    'MISC': '_'},
#   '4': {'ID': '4',
#    'FORM': 'militär',
#    'LEMMA': 'militär',
#    'UPOS': 'NOUN',
#    'XPOS': 'NN|UTR|SIN|IND|NOM',
#    'FEATS': 'Case=Nom|Definite=Ind|Gender=Com|Number=Sing',
#    'HEAD': '2',
#    'DEPREL': 'obl',
#    'DEPS': '2:obl:till',
#    'MISC': '_'}}]

# %% [markdown]
# ### Extracting the subject-verb pairs

# %% [markdown]
# Now you will extract the subject-verb pairs, where you will set the words in lowercase. In the second sentence of the corpus, this corresponds to `(beskattning, införs)`. You will call the function `extract_pairs(formatted_corpus_dict)` and and you will store the results in a `pairs_sv` variable. All the corpora in the universal dependencies format use the same function names: `nsubj` and `obj` for the subject and direct object.
#
# You can use the algorithm you want. However, here are some hints on the results:
# * You will extract all the subject-verb pairs in the corpus. In the extraction, just check the function between two words. Do not check if the part of speech is a verb or a noun in the pair. You will also ignore the possible function suffixes as in `nsubj:pass`, where `pass` means passive.
# * You will return the results as Python's dictionaries, where the key will be the pair and the value, the count, as for instance `{(beskattning, införs): 1}`. Be sure you understand the Python dictionaries and note that you can use tuples as keys.

# %%
# Write your code here
DEPREL = "DEPREL"
HEAD = "HEAD"
FORM = "FORM"
regex_before_dots = "nsubj"

def extract_pairs(formatted_corpus_dict):
    sub_verb_dict = {}
    
    for sentence in formatted_corpus_dict: 
        for word_info in sentence.values():
            dependency_form = word_info[DEPREL]

            if re.match(regex_before_dots, dependency_form):
                index = word_info[HEAD]
                head_form = sentence[index][FORM].lower()

                form = word_info[FORM].lower();
                tupel = (form, head_form)

                if tupel in sub_verb_dict:
                    sub_verb_dict[tupel] += 1
                else:
                    sub_verb_dict[tupel] = 1
                    
    return sub_verb_dict

# %%
pairs_sv = extract_pairs(formatted_corpus_dict)

# %% [markdown]
# You will compute the total number of subject-verb pairs. You should find 6,083 pairs.

# %%
sum([pairs_sv[pair] for pair in pairs_sv])
# Out:
# 6083

# %% [markdown]
# #### Finding the most frequent pairs

# %% [markdown]
# You will sort your pairs by frequency and by lexical order of the pairs and store the five most frequent pairs in the `freq_pairs_sv` variable as in:
# ```
# freq_pairs_sv = [(('som', 'har'), 45),
#
#  ...]
#  ````
#
# Here are the frequencies you should find:
# ```
# 45
# 19
# 19
# ```

# %% [markdown]
# In all the experiments, we will keep the `nbest` most frequent. In the first experiments, we set `nbest` to 3 first. We will set it to 5 in the last experiment.

# %%
nbest = 3

# %%
sorted_pairs = sorted(pairs_sv, key=lambda x: (-pairs_sv[x], x))
freq_pairs_sv = [(pair, pairs_sv[pair]) for pair in sorted_pairs][:nbest]

# %%
freq_pairs_sv
# Out:
# [(('som', 'har'), 45), (('du', 'får'), 19), (('vi', 'har'), 19)]

# %% [markdown]
# ### Extracting the subject-verb-object triples

# %% [markdown]
# You will now extract all the subject–verb–object triples of the corpus. The object function uses the `obj` code.

# %%
# Write your code here
def extract_triples(formatted_corpus_dict):
    sub_verb_dict = {}
    
    for sentence in formatted_corpus_dict: 
        sentence_verb_dict = {}
        
        for word_info in sentence.values():
            dependency_form = word_info[DEPREL]
            obj = re.match("obj", dependency_form)
            nsubj = re.match("nsubj", dependency_form)

            if obj or nsubj:
                form = word_info[FORM].lower();
                index_verb = word_info[HEAD]
                
                verb_form = sentence[index_verb][FORM].lower()
                
                if index_verb in sentence_verb_dict:
                    tupel = ()
                    
                    if obj:
                        tupel = (sentence_verb_dict[index_verb].lower(), verb_form, form)
                    else:
                        tupel = (form, verb_form, sentence_verb_dict[index_verb].lower())
                        
                    if tupel in sub_verb_dict:
                        sub_verb_dict[tupel] += 1
                    else:
                        sub_verb_dict[tupel] = 1
                else:
                    sentence_verb_dict[index_verb] = form;
                
                    
    return sub_verb_dict

# %%
triples_sv = extract_triples(formatted_corpus_dict)

# %% [markdown]
# Compute the total number of triples. You should find 2054 triples.

# %%
sum([triples_sv[triple] for triple in triples_sv])
# Out:
# 2054

# %% [markdown]
# #### Finding the most frequent triples

# %% [markdown]
# You will sort your triples by frequency and by lexical order of the pairs and store the three most frequent triples in the `freq_triples_sv` variable as in:
# ```
# freq_triples_sv = [(('man', 'vänder', 'sig'), 14),
#
#  ...]
#  ````
#
# Here are the frequencies you should find:
# ```
# 14
# 5
# 3
# ```

# %%
sorted_triples = sorted(triples_sv, key=lambda x: (-triples_sv[x], x))
freq_triples_sv = [(triple, triples_sv[triple]) for triple in sorted_triples][:nbest]

# %%
freq_triples_sv
# Out:
# [(('man', 'vänder', 'sig'), 14),
#  (('det', 'rör', 'sig'), 5),
#  (('man', 'söker', 'arbete'), 3)]

# %% [markdown]
# ### Multilingual Corpora

# %% [markdown]
# Once your program is working on Swedish, you will apply it to all the other languages in universal dependencies. The code below returns all the files from a folder with a suffix. Here we consider the training files only.

# %%
def get_files(dir, suffix):
    """
    Returns all the files in a folder ending with suffix
    Recursive version
    :param dir:
    :param suffix:
    :return: the list of file names
    """
    files = []
    for file in os.listdir(dir):
        path = dir + '/' + file
        if os.path.isdir(path):
            files += get_files(path, suffix)
        elif os.path.isfile(path) and file.endswith(suffix):
            files.append(path)
    return files

# %%
files = get_files(ud_path, 'train.conllu')

# %% [markdown]
# #### Dealing with the indices

# %% [markdown]
# Some corpora expand some tokens into multiwords. This is the case in French, Spanish, and German.
#         The table below shows examples of such expansions.
#         <table style="width:100%">
#             <tr>
#                 <th>French</th>
#                 <th>Spanish</th>
#                 <th>German</th>
#             </tr>
#             <tr>
#                 <td><i>du</i>: de le
#                 </td>
#                 <td><i>del</i>: de el
#                 </td>
#                 <td><i>zur</i>: zu der
#                 </td>
#             </tr>
#             <tr>
#                 <td><i>des</i>: de les
#                 </td>
#                 <td><i>vámonos</i>: vamos nos
#                 </td>
#                 <td><i>im</i>: in dem
#                 </td>
#             </tr>
#         </table>
#         In the corpora, you have the original tokens as well as the multiwords as with <i>vámonos al mar</i>.
#         <pre>
# 1-2 vámonos _
# 1 vamos ir
# 2 nos nosotros
# 3-4 al _
# 3 a a
# 4 el el
# 5 mar mar
# </pre>Read the format description for the details: [<a
#                 href="http://universaldependencies.org/format.html">CoNLL-U format</a>].

# %% [markdown]
# If you represent the sentences as lists, the item indices are not reliable: In the format description,
#         the token at position 1 is <i>vamos</i> and not <i>vámonos</i>.
#         You have two ways to cope with this:
# 1. Either remove all the lines that include a range in the `ID` field, or
# 2. Encode the sentences as dictionaries (I felt this was preferable), where the keys are the `ID` numbers. This is what `convert_to_dict()` does. Here are the results for a sentence from the French CoNLL-U corpus:
# _Les iris du mâles sont jaunes toute l'année._ Note the `3-4` index and it expansion in `3`and `4`:
# ```
# {'0': {'ID': '0',  'FORM': 'ROOT',  'LEMMA': 'ROOT',  'UPOS': 'ROOT',  'XPOS': 'ROOT',  'FEATS': 'ROOT',  'HEAD': '0',  'DEPREL': 'ROOT',  'DEPS': '0',  'MISC': 'ROOT'},
# '1': {'ID': '1',  'FORM': 'Les',  'LEMMA': 'le',  'UPOS': 'DET',  'XPOS': '_',  'FEATS': 'Definite=Def|Gender=Masc|Number=Plur|PronType=Art',  'HEAD': '2',  'DEPREL': 'det',  'DEPS': '_',  'MISC': 'wordform=les'},
# '2': {'ID': '2',  'FORM': 'iris',  'LEMMA': 'iris',  'UPOS': 'NOUN',  'XPOS': '_',  'FEATS': 'Gender=Masc|Number=Plur',  'HEAD': '7',  'DEPREL': 'nsubj',  'DEPS': '_',  'MISC': '_'},
# '3-4': {'ID': '3-4',  'FORM': 'du',  'LEMMA': '_',  'UPOS': '_',  'XPOS': '_',  'FEATS': '_',  'HEAD': '_',  'DEPREL': '_',  'DEPS': '_',  'MISC': '_'},
# '3': {'ID': '3',  'FORM': 'de',  'LEMMA': 'de',  'UPOS': 'ADP',  'XPOS': '_',  'FEATS': '_',  'HEAD': '5',  'DEPREL': 'case',  'DEPS': '_',  'MISC': '_'},
# '4': {'ID': '4',  'FORM': 'le',  'LEMMA': 'le',  'UPOS': 'DET',  'XPOS': '_',  'FEATS': 'Definite=Def|Gender=Masc|Number=Sing|PronType=Art',  'HEAD': '5',  'DEPREL': 'det',  'DEPS': '_',  'MISC': '_'},
# '5': {'ID': '5',  'FORM': 'mâles',  'LEMMA': 'mâle',  'UPOS': 'NOUN',  'XPOS': '_',  'FEATS': 'Gender=Masc|Number=Plur',  'HEAD': '2',  'DEPREL': 'nmod',  'DEPS': '_',  'MISC': '_'},
# '6': {'ID': '6',  'FORM': 'sont',  'LEMMA': 'être',  'UPOS': 'AUX',  'XPOS': '_',  'FEATS': 'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',  'HEAD': '7',  'DEPREL': 'cop',  'DEPS': '_',  'MISC': '_'},
# '7': {'ID': '7',  'FORM': 'jaunes',  'LEMMA': 'jaune',  'UPOS': 'ADJ',  'XPOS': '_',  'FEATS': 'Gender=Masc|Number=Plur',  'HEAD': '0',  'DEPREL': 'root',  'DEPS': '_',  'MISC': '_'},
# '8': {'ID': '8',  'FORM': 'toute',  'LEMMA': 'tout',  'UPOS': 'ADJ',  'XPOS': '_',  'FEATS': 'Gender=Fem|Number=Sing',  'HEAD': '10',  'DEPREL': 'amod',  'DEPS': '_',  'MISC': '_'},
# '9': {'ID': '9',  'FORM': "l'",  'LEMMA': 'le',  'UPOS': 'DET',  'XPOS': '_',  'FEATS': 'Definite=Def|Gender=Fem|Number=Sing|PronType=Art',  'HEAD': '10',  'DEPREL': 'det',  'DEPS': '_',  'MISC': 'SpaceAfter=No'},
# '10': {'ID': '10',  'FORM': 'année',  'LEMMA': 'année',  'UPOS': 'NOUN',  'XPOS': '_',  'FEATS': 'Gender=Fem|Number=Sing',  'HEAD': '7',  'DEPREL': 'obl',  'DEPS': '_',  'MISC': 'SpaceAfter=No'},
# '11': {'ID': '11',  'FORM': '.',  'LEMMA': '.',  'UPOS': 'PUNCT',  'XPOS': '_',  'FEATS': '_',  'HEAD': '7',  'DEPREL': 'punct',  'DEPS': '_',  'MISC': '_'}}
# ```
# 3. Some corpora have sentence numbers. You solve it by discarding lines starting with a `#`. This is already done in the CoNLL reader.

# %% [markdown]
# #### Extracting the pairs and triples

# %% [markdown]
# Write a function `extract_pairs_and_triples(formatted_corpus_dict, nbest)` that extracts the `nbest` most frequent pairs and triples of a given corpus and returns two sorted lists of tuples: `frequent_pairs` and `frequent_triples`. You will sort them by frequency and then by alphabetical order of the pair or triple.

# %%
# Write your code here
def extract_pairs_and_triples(formatted_corpus_dict, nbest):
    pairs_un = extract_pairs(formatted_corpus_dict)
    triples_un = extract_triples(formatted_corpus_dict)
    
    sorted_pairs = sorted(pairs_un, key=lambda x: (-pairs_un[x], x))
    freq_pairs = [(pair, pairs_un[pair]) for pair in sorted_pairs][:nbest]
    
    sorted_triples = sorted(triples_un, key=lambda x: (-triples_un[x], x))
    freq_triples = [(triple, triples_un[triple]) for triple in sorted_triples][:nbest]
    
    return (freq_pairs, freq_triples)

# %% [markdown]
# Run your extractor on all the corpora. Note that some corpora have replaced the words by underscores as for one corpus n French. You need then to contact the provider to obtain them.

# %%
# Write your code here

def corpora_extractor(file):
    sentences = read_sentences(file)   
    formatted_corpus = split_rows(sentences, column_names_u)
    formatted_corpus_dict = convert_to_dict(formatted_corpus)
    
    return(formatted_corpus_dict)

# %% [markdown]
# In your report, you will include the `nbest` most frequent pairs and triples you obtained in **three languages**. You may choose the ones you want.
#
# For the checking script, you will extract `nbest` triples in French, Russian, and English. You will rank these triples by frequency, and then by alphabetical order of the triple using `sorted()`. You will use the French GSD corpus, the Russian SynTagRus corpus, and the English EWT corpus. You will store these triples in the following variables:
# `freq_triples_fr`, `freq_triples_ru`, `freq_triples_en`. Each variable will contain a list of tuples: `(subject, verb, object), freq)`
#
# Here is what you should find:
#
# French
# ```
# freq_triples_fr = [(('il', 'fait', 'partie'), 16),
#
#  ...]
#  ````
#
# And the frequencies:
# ```
# 16
# 7
# 7
# ```
#
# Russian:
# ```
# freq_triples_ru = [(('мы', 'имеем', 'дело'), 6),
#
#  ...]
#  ````
#
# And the frequencies:
# ```
# 6
# 4
# 4
# ```
#
# English:
# ```
# freq_triples_en = [(('you', 'have', 'questions'), 22),
#
#  ...]
#  ````
#
# And the frequencies:
# ```
# 22
# 12
# 7
# ```

# %%
files = [path_fr, path_ru, path_en]

# %%
# Write your code here
formatted_corpus_dict = corpora_extractor(files[0])

# %%
freq_pairs_fr, freq_triples_fr = extract_pairs_and_triples(formatted_corpus_dict, nbest)
freq_triples_fr
# Out:
# [(('il', 'fait', 'partie'), 16),
#  (('elle', 'fait', 'partie'), 7),
#  (('il', 'comptait', 'habitants'), 7)]

# %%
# Write your code here
formatted_corpus_dict = corpora_extractor(files[1])

# %%
freq_pairs_ru, freq_triples_ru = extract_pairs_and_triples(formatted_corpus_dict, nbest)
freq_triples_ru
# Out:
# [(('мы', 'имеем', 'дело'), 6),
#  (('мы', 'имеем', 'что'), 4),
#  (('мы', 'сделаем', 'все'), 4)]

# %%
# Write your code here
formatted_corpus_dict = corpora_extractor(files[2])

# %%
freq_pairs_en, freq_triples_en = extract_pairs_and_triples(formatted_corpus_dict, nbest)
freq_triples_en
# Out:
# [(('you', 'have', 'questions'), 22),
#  (('you', 'think', 'what'), 12),
#  (('i', 'do', 'what'), 7)]

# %% [markdown]
# ## Resolving the entities

# %% [markdown]
# You will now extract the relations involving named entities, that is where both the subject and the object are proper nouns.
#
# Write an `extract_entity_triples(formatted_corpus_dict)` that will process the corpus and return a list of `(subject, verb, object)` triples. You will leave the case as it is in the form, for instance _United States_ and not _united states_.

# %%
# Write your code here
def extract_entity_triples(formatted_corpus_dict):
    entity_list = []
    
    for sentence in formatted_corpus_dict: 
        sentence_verb_dict = {}
        
        for word_info in sentence.values():
            
            dependency_form = word_info[DEPREL]
            obj = re.match("obj", dependency_form)
            nsubj = re.match("nsubj", dependency_form)
            p_noun = re.match("NNP|NNPS", word_info['XPOS'])

            if (obj or nsubj) and p_noun:
                form = word_info[FORM];
                index_verb = word_info[HEAD]
                
                verb_form = sentence[index_verb][FORM]
                
                if index_verb in sentence_verb_dict:
                    tupel = ()
                    
                    if obj:
                        tupel = (sentence_verb_dict[index_verb], verb_form, form)
                    else:
                        tupel = (form, verb_form, sentence_verb_dict[index_verb])
                        
                    entity_list.append(tupel)
                else:
                    sentence_verb_dict[index_verb] = form;
                
                    
    return entity_list

# %% [markdown]
# You will run the `extract_entity_triples()` function one the English EWT corpus. You will store the list in the `entity_relation_en` variable and you will sort it with `sorted()`. You will keep the **five** first triples.

# %%
nbest = 5

# %% [markdown]
# The two first triples are:
# ```
# [('Baba', 'remember', 'George'),
#  ('Beschta', 'told', 'Planet'),
# ...]
#  ```
# Note that this time, we keep the original case and the triples are in the alphabetical order.

# %%
#Write your code here
file = path_en
formated_corpus = corpora_extractor(file)

entity_relation_en = extract_entity_triples(formated_corpus)

# %%
entity_relation_en = sorted(entity_relation_en)[:nbest]
entity_relation_en
# Out:
# [('Baba', 'remember', 'George'),
#  ('Beschta', 'told', 'Planet'),
#  ('Boi', 'beat', 'Lopez'),
#  ('Bush', 'mentioned', 'Arabia'),
#  ('Bush', 'mentioned', 'Osama')]

# %% [markdown]
# ### Optional exercise: Extracting the chunks

# %% [markdown]
# Extracting only the headword of the subject and object if often incomplete and uninformative. You can extract all the chunk instead. As an optional exercise, you can try a baseline technique and extract adjacent proper nouns. You may also want to apply the chunker of the 4th assignment to the corpus to do this.

# %% [markdown]
# ### Optional exercise: Mapping the entities

# %% [markdown]
# As in the chunker assignment, you may also want to complement your assignment with a entity solver that will link the entities to wikidata.

# %% [markdown]
# ## Reading

# %% [markdown]
# Read the article: _PRISMATIC: Inducing Knowledge from a Large Scale Lexicalized Relation Resource_ by Fan and al. (2010) [<a href="http://www.aclweb.org/anthology/W/W10/W10-0915.pdf">pdf</a>] and write in a few sentences how it relates to your work in this assignment.

# %% [markdown]
# ## Submission

# %% [markdown]
# When you have written all the code and run all the cells, fill in your ID and as well as the name of the notebook.

# %%
STIL_ID = ["vi1146ol-s"] # Write your stil ids as a list
CURRENT_NOTEBOOK_PATH = os.path.join(os.getcwd(), 
                                     "5-triples.ipynb") # Write the name of your notebook

# %% [markdown]
# The submission code will send your answer. It consists of the pairs and triples in four languages, as well as the triples with named entities.

# %%
import json
ANSWER = json.dumps({'freq_triples_sv': freq_triples_sv,
                     'freq_triples_fr': freq_triples_fr,
                     'freq_triples_ru': freq_triples_ru,
                     'freq_triples_en': freq_triples_en,
                     'entity_relation_en': entity_relation_en
                    })
ANSWER
# Out:
# '{"freq_triples_sv": [[["man", "v\\u00e4nder", "sig"], 14], [["det", "r\\u00f6r", "sig"], 5], [["man", "s\\u00f6ker", "arbete"], 3]], "freq_triples_fr": [[["il", "fait", "partie"], 16], [["elle", "fait", "partie"], 7], [["il", "comptait", "habitants"], 7]], "freq_triples_ru": [[["\\u043c\\u044b", "\\u0438\\u043c\\u0435\\u0435\\u043c", "\\u0434\\u0435\\u043b\\u043e"], 6], [["\\u043c\\u044b", "\\u0438\\u043c\\u0435\\u0435\\u043c", "\\u0447\\u0442\\u043e"], 4], [["\\u043c\\u044b", "\\u0441\\u0434\\u0435\\u043b\\u0430\\u0435\\u043c", "\\u0432\\u0441\\u0435"], 4]], "freq_triples_en": [[["you", "have", "questions"], 22], [["you", "think", "what"], 12], [["i", "do", "what"], 7]], "entity_relation_en": [["Baba", "remember", "George"], ["Beschta", "told", "Planet"], ["Boi", "beat", "Lopez"], ["Bush", "mentioned", "Arabia"], ["Bush", "mentioned", "Osama"]]}'

# %% [markdown]
# Now the moment of truth:
# 1. Save your notebook and
# 2. Run the cells below

# %%
SUBMISSION_NOTEBOOK_PATH = CURRENT_NOTEBOOK_PATH + ".submission.bz2"

# %%
import bz2
ASSIGNMENT = 5
API_KEY = "f581ba347babfea0b8f2c74a3a6776a7"

# Copy and compress current notebook
with bz2.open(SUBMISSION_NOTEBOOK_PATH, mode="wb") as fout:
    with open(CURRENT_NOTEBOOK_PATH, "rb") as fin:
        fout.write(fin.read())

# %%
import requests
res = requests.post("https://vilde.cs.lth.se/edan20checker/submit", 
                    files={"notebook_file": open(SUBMISSION_NOTEBOOK_PATH, "rb")}, 
                    data={
                        "stil_id": STIL_ID,
                        "assignment": ASSIGNMENT,
                        "answer": ANSWER,
                        "api_key": API_KEY,
                    },
               verify=True)

# from IPython.display import display, JSON
res.json()
# Out:
# {'msg': None,
#  'status': 'correct',
#  'signature': '6b73e7f5251d7e95757b51e73653843bd13e27ea184697e692f0a4c8ebae932eb89cd5d9f23a296a8afdfaca868cfb6de8ea19559da34ecbcd7f0007ce4a7f90',
#  'submission_id': '58395776-b509-45fc-93c4-afc0258b5037'}
